# %% [markdown]
# # We gathered the data from an S3 bucket hosted on the AWS cloud and then mounted it into our Google Drive (or personal Drive). We did this because accessing the file from Drive is faster than accessing it directly from the S3 bucket

# %%
! uv pip install boto3 cmapPy
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 17 packages in 645ms
# Prepared 5 packages in 667ms
# Installed 5 packages in 79ms
#  + boto3==1.42.2
#  + botocore==1.42.2
#  + cmappy==4.0.1
#  + jmespath==1.0.1
#  + s3transfer==0.16.0

# %%
from google.colab import drive
import boto3
from google.colab import userdata
import gzip
import shutil
import pandas as pd
from cmapPy.pandasGEXpress import parse

drive.mount('/content/drive')

# Corrected the boto3.client call to use keyword arguments for credentials
# and added a placeholder for region_name.
s3 = boto3.client('s3',
                  aws_access_key_id=userdata.get('aws_access_key_id'),
                  aws_secret_access_key=userdata.get('AWS_SECRET_ACCESS_KEY'),
                  region_name='eu-north-1')

bucket_name = 'amarchs3'
file_key = 'Lincs_data/raw/lincs_l1000/signatures/GSE70138_Broad_LINCS_Level5_COMPZ_n118050x12328_2017-03-06.gctx.gz'
destination = '/content/drive/MyDrive/GSE70138.gctx.gz'

s3.download_file(bucket_name, file_key, destination)

print("Téléchargement terminé !")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Téléchargement terminé !
